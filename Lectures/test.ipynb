# %%
import numpy as np
import matplotlib.pyplot as plt
import Met_Num.root as mr

# %% [markdown]
# $$f(x)=3x^2+9x$$

# %%
p = lambda x: 3*x**2 + 9*x
interv = [-5, 5]

mr.roo_Bis(p, interv, Nit=1000, error='dist', eps=1e-05, Ndiv=100000)
# Out:
# [-2.9999987499875003, -6.250062500157139e-06]

# %%
mr.Findinterv(p, interv, Ndiv=100000)
# Out:
# [[-3.0000800008000077, -2.999979999799998],
#  [-5.000050000436573e-05, 5.000050000525391e-05]]

# %%
xval = np.linspace(interv[0], interv[1], 1000)
plt.plot(xval, p(xval))
plt.hlines(y=0, xmin=-5, xmax=5, color='k', ls='--')
